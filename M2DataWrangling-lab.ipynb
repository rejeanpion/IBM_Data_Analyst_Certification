# %% [markdown]
# <center>
#     <img src="https://gitlab.com/ibm/skills-network/courses/placeholder101/-/raw/master/labs/module%201/images/IDSNlogo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify duplicate values in the dataset.
#
# *   Remove duplicate values from the dataset.
#
# *   Identify missing values in the dataset.
#
# *   Impute the missing values in the dataset.
#
# *   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
# Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here
index = df.index
number_of_rows = len(index)
print("the number of total rows is: " + str(number_of_rows))
print("the number of duplicated rows is: " + str(df.duplicated().sum()))
# Out:
# the number of total rows is: 11552
# the number of duplicated rows is: 154

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here
df.loc[df.duplicated(), :]
df.loc[df.duplicated(keep='first'), :]
df.drop_duplicates(inplace=True, keep='first')

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here
index = df.index
number_of_rows = len(index)
print("the number of total rows is: " + str(number_of_rows))
print("the number of duplicated rows is: " + str(df.duplicated().sum()))
# Out:
# the number of total rows is: 11398
# the number of duplicated rows is: 0

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here
df.dtypes.value_counts()
df.dtypes == 'object'
# Out:
# Respondent      False
# MainBranch       True
# Hobbyist         True
# OpenSourcer      True
# OpenSource       True
#                 ...
# Sexuality        True
# Ethnicity        True
# Dependents       True
# SurveyLength     True
# SurveyEase       True
# Length: 85, dtype: bool

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# BlockchainIs          2610
# CodeRevHrs            2426
# BlockchainOrg         2322
# MiscTechWorkedWith    2182
# SONewContent          1965
#                       ...
# MainBranch               0
# CurrencySymbol           0
# CurrencyDesc             0
# WorkLoc                  0
# Respondent               0
# Length: 85, dtype: int64

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here

df['Country'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here
df['CompFreq'].value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#make a note of the majority value here, for future reference

df['CompFreq'].describe()
# Out:
# count      11192
# unique         3
# top       Yearly
# freq        6073
# Name: CompFreq, dtype: object

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes here
df['WorkLoc'].fillna("Office", inplace = True)

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here
df['WorkLoc'].isna().sum()
# Out:
# 0

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
df['CompFreq'].value_counts()
# Out:
# Yearly     6073
# Monthly    4788
# Weekly      331
# Name: CompFreq, dtype: int64

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
# List all the salary values in descinding order of occurence
df['CompTotal'].value_counts().sort_values(ascending=False)
# Out:
# 70000.0     241
# 60000.0     239
# 50000.0     223
# 100000.0    218
# 80000.0     194
#            ...
# 774.0         1
# 86240.0       1
# 39700.0       1
# 529000.0      1
# 74400.0       1
# Name: CompTotal, Length: 1509, dtype: int64

# %%
# your code goes here
df2 = df[['CompFreq', 'CompTotal']]
df2['NormalizedAnnualSalary'] = ""
df2.head()
# Out:
# C:\Users\rejea\AppData\Local\Temp/ipykernel_32052/884231369.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['NormalizedAnnualSalary'] = ""
#   CompFreq  CompTotal NormalizedAnnualSalary
# 0   Yearly    61000.0
# 1   Yearly   138000.0
# 2   Yearly    90000.0
# 3  Monthly    29000.0
# 4   Yearly    90000.0

# %%
if df2.loc[df['CompFreq']] == 'Yearly':
    print('Yearly')
elif df2.loc[df['CompFreq']] == 'Monthly':
    print('Monthly')
elif df2.loc[df['CompFreq']] == 'Weekly':
    print('Weekly')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32052/518651839.py in <module>
# ----> 1 if df2.loc[df['CompFreq']] == 'Yearly':
#       2     print('Yearly')
#       3 elif df2.loc[df['CompFreq']] == 'Monthly':
#       4     print('Monthly')
#       5 elif df2.loc[df['CompFreq']] == 'Weekly':
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1151                     raise ValueError("Cannot index with multidimensional key")
#    1152
# ...

# %%
if df2['CompFreq'] == 'Yearly':
    df2.loc[df2[NormalizedAnnualSalary]] = df2['CompTotal']
elif df2['CompFreq'] == 'Monthly':
    df2.loc[df2[NormalizedAnnualSalary]] = df2['CompTotal'] * 12
elif df2['CompFreq'] == 'Weekly':
    df2.loc[df2[NormalizedAnnualSalary]] = df2['CompTotal'] * 52

df2.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_32052/707277006.py in <module>
#       1 #for row in df2.iterrows():
# ----> 2 if df2['CompFreq'] == 'Yearly':
#       3     df2.loc[df2[NormalizedAnnualSalary]] = df2['CompTotal']
#       4 elif df2['CompFreq'] == 'Monthly':
#       5     df2.loc[df2[NormalizedAnnualSalary]] = df2['CompTotal'] * 12
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1532     @final
#    1533     def __nonzero__(self):
# -> 1534         raise ValueError(
#    1535             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1536             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer\&utm_source=Exinfluencer\&utm_content=000026UJ\&utm_term=10006555\&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2021-01-01\&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264\&cm_mmca1=000026UJ\&cm_mmca2=10006555\&cm_mmca3=M12345678\&cvosrc=email.Newsletter.M12345678\&cvo_campaign=000026UJ).
